# %% [markdown]
# That one was tough too, more than the last one to my mind

# %%
##CODE FOR SOLUTION

def f(x,y,z):
    return (3*( 2**x + 2**y - 2+ 2**z - 2)) * 2**((x + y + z - 1))

# %%
f(9,10,11)
# Out:
# 5765993594880

# %% [markdown]
# I first did the case f(1, 1, z) and then f(1,y,z) which gave me ideas on how to do it.
# I used arrows for each pair {1,6}, {3,4} and {2,5} which are the opposite pairs on a dice or here can be think as directions. each dice is asking for 3 directions that must be different. The thing is if you move 2 of them, the other one has to be the same all the time. If I move x,y between rows and columns, then x has to always be the same pair and you have 2 choices for (x,y).
# First you count all possibilities with this pairs, you just have 3 cases: which axis you choose to be uniform and then you choose 2 pairs along this axis on each layer.
# You don't have to forget to substract the cases where everything is uniform because you already count it with 2^x, so when putting z or y uniform you subtract 2 2 times.
# Then you have to choose if our pair is for example {1,6} or {6,1} so multiply everyting by 2^(2 + x - 1 + y-1 + z-1): you first have 2 dof for the first dice, then p-1 for the p-1 dices over the axis p since 1 axis is forced by the constraints of the problem (you have 2 left) and by chosing 1 other axis, the other is constraint too by the structure of the dice.
